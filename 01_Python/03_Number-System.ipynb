# %%
bin(25)
# Out:
# '0b11001'

# %%
int(0b11001)
# Out:
# 25

# %%
int(0x19)
# Out:
# 25

# %%
12 & 13
# Out:
# 12

# %%
12 | 13
# Out:
# 13

# %%
12 ^ 13
# Out:
# 1

# %%
12 << 2
# Out:
# 48

# %%
12 << 1
# Out:
# 24

# %%
12 >> 1
# Out:
# 6
