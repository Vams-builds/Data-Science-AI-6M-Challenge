# %%
l = [] # empty list
l
# Out:
# []

# %%
type(l)
# Out:
# list

# %%
len(l)
# Out:
# 0

# %%
l.append(10)
l
# Out:
# [10]

# %%
len(l)
# Out:
# 1

# %%
l.append(10, 20, 30)    # only one argument can be passed
l
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 l.append(10, 20, 30)    # only one argument can be passed
#       2 l
#
# TypeError: list.append() takes exactly one argument (3 given)

# %%
l.append(20)
l.append(30)
l.append(30)
l.append(50)
l
# Out:
# [10, 20, 30, 30, 50]

# %%
len(l)
# Out:
# 5

# %%
l.append(10) # duplication is allowed in list
l
# Out:
# [10, 20, 30, 30, 50, 10]

# %%
l1 = [10, 3.5, "vamshi", True, (2+4j)]
l1
# Out:
# [10, 3.5, 'vamshi', True, (2+4j)]

# %%
l1.append([1,2,3]) # list inside a list ---> Nested List
l1
# Out:
# [10, 3.5, 'vamshi', True, (2+4j), [1, 2, 3]]

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 30, 50, 10]
# [10, 3.5, 'vamshi', True, (2+4j), [1, 2, 3]]

# %%
l3 = l.copy()
l3
# Out:
# [10, 20, 30, 30, 50, 10]

# %%
print(l)
print(l1)
print(l3)
# Out:
# [10, 20, 30, 30, 50, 10]
# [10, 3.5, 'vamshi', True, (2+4j), [1, 2, 3]]
# [10, 20, 30, 30, 50, 10]

# %%
l == l3
# Out:
# True

# %%
len(l) == len(l3)
# Out:
# True

# %%
print(id(l) == id(l3)) # id's are not equal even if values are equal

print(id(l))
print(id(l3))
# Out:
# False
# 2601958347520
# 2601958537216

# %%
l3.clear()
l3
# Out:
# []

# %%
del l3

# %%
l3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 l3
#
# NameError: name 'l3' is not defined

# %%
l.count(10)
# Out:
# 2

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 30, 50, 10]
# [10, 3.5, 'vamshi', True, (2+4j), [1, 2, 3]]

# %%
l.extend(l1)
l
# Out:
# [10, 20, 30, 30, 50, 10, 10, 3.5, 'vamshi', True, (2+4j), [1, 2, 3]]

# %%
a = [1,2,3]
b = [4,5,6]

# %%
a.extend(b)
a
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
print(a)
print(b)
# Out:
# [1, 2, 3, 4, 5, 6]
# [4, 5, 6]

# %%
l.index(10)
# Out:
# 0

# %%
b.index(6)
# Out:
# 2

# %%
l[:]
# Out:
# [10, 20, 30, 30, 50, 10, 10, 3.5, 'vamshi', True, (2+4j), [1, 2, 3]]

# %%
l[::3]
# Out:
# [10, 30, 10, True]

# %%
l[:3]
# Out:
# [10, 20, 30]

# %%
l[::-1] # Reverse the list
# Out:
# [[1, 2, 3], (2+4j), True, 'vamshi', 3.5, 10, 10, 50, 30, 30, 20, 10]

# %%
l[3]
# Out:
# 30

# %%
l
# Out:
# [10, 20, 30, 30, 50, 10, 10, 3.5, 'vamshi', True, (2+4j), [1, 2, 3]]

# %%
l[-4]
# Out:
# 'vamshi'

# %%
print(l[-4][0])
print(l[-4][1])
print(l[-4][2])
print(l[-4][3])
print(l[-4][4])
print(l[-4][5])

# nested indexing
# Out:
# v
# a
# m
# s
# h
# i

# %%
l
# Out:
# [10, 20, 30, 30, 50, 10, 10, 3.5, 'vamshi', True, (2+4j), [1, 2, 3]]

# %%
l[0] = 1000

# %%
l
# Out:
# [1000, 20, 30, 30, 50, 10, 10, 3.5, 'vamshi', True, (2+4j), [1, 2, 3]]
